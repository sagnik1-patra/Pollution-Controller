# %%
# Earth Engine API
# !pip install earthengine-api
# !pip install geemap

# Data Handling
# !pip install pandas numpy matplotlib seaborn

# Deep Learning
# !pip install tensorflow keras

# Mapping
# !pip install folium
# Out:
# Collecting earthengine-api
#   Downloading earthengine_api-1.5.24-py3-none-any.whl.metadata (2.1 kB)
# Collecting google-cloud-storage (from earthengine-api)
#   Downloading google_cloud_storage-3.2.0-py3-none-any.whl.metadata (13 kB)
# Collecting google-api-python-client>=1.12.1 (from earthengine-api)
#   Downloading google_api_python_client-2.176.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.40.3)
# Collecting google-auth-httplib2>=0.0.3 (from earthengine-api)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting httplib2<1dev,>=0.9.2 (from earthengine-api)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: requests in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.1)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client>=1.12.1->earthengine-api)
#   Downloading google_api_core-2.25.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=1.12.1->earthengine-api)
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (3.20.3)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->earthengine-api)
#   Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->earthengine-api)
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->earthengine-api)
#   Downloading google_crc32c-1.7.1-cp311-cp311-win_amd64.whl.metadata (2.4 kB)
# Downloading earthengine_api-1.5.24-py3-none-any.whl (464 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading google_api_python_client-2.176.0-py3-none-any.whl (13.7 MB)
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.7 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.7 MB 932.9 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/13.7 MB 1.0 MB/s eta 0:00:13
#    --- ------------------------------------ 1.0/13.7 MB 1.2 MB/s eta 0:00:11
#    --- ------------------------------------ 1.3/13.7 MB 1.3 MB/s eta 0:00:10
#    ----- ---------------------------------- 1.8/13.7 MB 1.3 MB/s eta 0:00:09
#    ------ --------------------------------- 2.1/13.7 MB 1.4 MB/s eta 0:00:09
#    ------ --------------------------------- 2.4/13.7 MB 1.4 MB/s eta 0:00:09
#    -------- ------------------------------- 2.9/13.7 MB 1.5 MB/s eta 0:00:08
#    --------- ------------------------------ 3.1/13.7 MB 1.5 MB/s eta 0:00:07
#    --------- ------------------------------ 3.4/13.7 MB 1.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 3.7/13.7 MB 1.5 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.9/13.7 MB 1.5 MB/s eta 0:00:07
#    ------------ --------------------------- 4.2/13.7 MB 1.5 MB/s eta 0:00:07
#    ------------- -------------------------- 4.7/13.7 MB 1.5 MB/s eta 0:00:07
#    -------------- ------------------------- 5.0/13.7 MB 1.4 MB/s eta 0:00:07
#    --------------- ------------------------ 5.2/13.7 MB 1.4 MB/s eta 0:00:06
#    --------------- ------------------------ 5.2/13.7 MB 1.4 MB/s eta 0:00:06
#    ---------------- ----------------------- 5.5/13.7 MB 1.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 6.0/13.7 MB 1.4 MB/s eta 0:00:06
#    ------------------ --------------------- 6.3/13.7 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 6.6/13.7 MB 1.4 MB/s eta 0:00:06
#    ------------------- -------------------- 6.8/13.7 MB 1.4 MB/s eta 0:00:05
#    -------------------- ------------------- 7.1/13.7 MB 1.4 MB/s eta 0:00:05
#    -------------------- ------------------- 7.1/13.7 MB 1.4 MB/s eta 0:00:05
#    --------------------- ------------------ 7.3/13.7 MB 1.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.9/13.7 MB 1.4 MB/s eta 0:00:05
#    ------------------------ --------------- 8.4/13.7 MB 1.4 MB/s eta 0:00:04
#    -------------------------- ------------- 8.9/13.7 MB 1.5 MB/s eta 0:00:04
#    -------------------------- ------------- 9.2/13.7 MB 1.5 MB/s eta 0:00:04
#    ----------------------------- ---------- 10.0/13.7 MB 1.5 MB/s eta 0:00:03
#    ------------------------------ --------- 10.5/13.7 MB 1.6 MB/s eta 0:00:03
#    ------------------------------- -------- 10.7/13.7 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 11.3/13.7 MB 1.6 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.8/13.7 MB 1.6 MB/s eta 0:00:02
#    ------------------------------------ --- 12.3/13.7 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  13.4/13.7 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.7/13.7 MB 1.7 MB/s eta 0:00:00
# Downloading google_api_core-2.25.1-py3-none-any.whl (160 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Downloading google_cloud_storage-3.2.0-py3-none-any.whl (176 kB)
# Downloading google_cloud_core-2.4.3-py2.py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.7.1-cp311-cp311-win_amd64.whl (33 kB)
# Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
# Installing collected packages: uritemplate, proto-plus, httplib2, googleapis-common-protos, google-crc32c, google-resumable-media, google-auth-httplib2, google-api-core, google-cloud-core, google-api-python-client, google-cloud-storage, earthengine-api
#
#    ---------- -----------------------------  3/12 [googleapis-common-protos]
#    ---------- -----------------------------  3/12 [googleapis-common-protos]
#    -------------------- -------------------  6/12 [google-auth-httplib2]
#    ----------------------- ----------------  7/12 [google-api-core]
#    ----------------------- ----------------  7/12 [google-api-core]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    ------------------------------ ---------  9/12 [google-api-python-client]
#    --------------------------------- ------ 10/12 [google-cloud-storage]
#    ------------------------------------ --- 11/12 [earthengine-api]
#    ------------------------------------ --- 11/12 [earthengine-api]
#    ------------------------------------ --- 11/12 [earthengine-api]
#    ---------------------------------------- 12/12 [earthengine-api]
#
# Successfully installed earthengine-api-1.5.24 google-api-core-2.25.1 google-api-python-client-2.176.0 google-auth-httplib2-0.2.0 google-cloud-core-2.4.3 google-cloud-storage-3.2.0 google-crc32c-1.7.1 google-resumable-media-2.7.2 googleapis-common-protos-1.70.0 httplib2-0.22.0 proto-plus-1.26.1 uritemplate-4.2.0
# Collecting geemap
#   Downloading geemap-0.35.3-py2.py3-none-any.whl.metadata (12 kB)
# Collecting bqplot (from geemap)
#   Downloading bqplot-0.12.45-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting colour (from geemap)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from geemap) (1.5.24)
# Collecting eerepr>=0.1.0 (from geemap)
#   Downloading eerepr-0.1.2-py3-none-any.whl.metadata (4.2 kB)
# Collecting folium>=0.17.0 (from geemap)
#   Downloading folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting geocoder (from geemap)
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting ipyevents (from geemap)
#   Downloading ipyevents-2.0.2-py3-none-any.whl.metadata (2.9 kB)
# Collecting ipyfilechooser>=0.6.0 (from geemap)
#   Downloading ipyfilechooser-0.6.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting ipyleaflet>=0.19.2 (from geemap)
#   Downloading ipyleaflet-0.20.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting ipytree (from geemap)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Requirement already satisfied: matplotlib in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from geemap) (3.7.3)
# Requirement already satisfied: numpy in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from geemap) (2.3.0)
# Collecting plotly (from geemap)
#   Downloading plotly-6.2.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting pyperclip (from geemap)
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyshp>=2.3.1 (from geemap)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Collecting python-box (from geemap)
#   Downloading python_box-7.3.2-cp311-cp311-win_amd64.whl.metadata (8.3 kB)
# Collecting scooby (from geemap)
#   Downloading scooby-0.10.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: google-cloud-storage in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (3.2.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.176.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.40.3)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api>=1.0.0->geemap) (3.2.1)
# Collecting branca>=0.6.0 (from folium>=0.17.0->geemap)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Collecting xyzservices (from folium>=0.17.0->geemap)
#   Downloading xyzservices-2025.4.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.25.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (3.20.3)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2025.1.31)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.6.1)
# Requirement already satisfied: ipywidgets in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.7)
# Collecting jupyter-leaflet<0.21,>=0.20 (from ipyleaflet>=0.19.2->geemap)
#   Downloading jupyter_leaflet-0.20.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting traittypes<3,>=0.2.1 (from ipyleaflet>=0.19.2->geemap)
#   Downloading traittypes-0.2.1-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.15)
# Requirement already satisfied: colorama in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.2)
# Requirement already satisfied: wcwidth in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas->geemap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->geemap) (1.17.0)
# Requirement already satisfied: click in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from geocoder->geemap) (8.1.8)
# Collecting future (from geocoder->geemap)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting ratelim (from geocoder->geemap)
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->geemap) (10.2.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from plotly->geemap) (1.46.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Downloading geemap-0.35.3-py2.py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.3 MB 8.3 MB/s eta 0:00:01
#    ------------------------------------ --- 2.1/2.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 7.1 MB/s eta 0:00:00
# Downloading eerepr-0.1.2-py3-none-any.whl (9.5 kB)
# Downloading folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Downloading ipyfilechooser-0.6.0-py3-none-any.whl (11 kB)
# Downloading ipyleaflet-0.20.0-py3-none-any.whl (31 kB)
# Downloading jupyter_leaflet-0.20.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 6.0 MB/s eta 0:00:00
# Downloading traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Downloading xyzservices-2025.4.0-py3-none-any.whl (90 kB)
# Downloading bqplot-0.12.45-py2.py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------------- ------ 1.0/1.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 4.8 MB/s eta 0:00:00
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading ipyevents-2.0.2-py3-none-any.whl (101 kB)
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------------------------------- ------- 1.0/1.3 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 6.0 MB/s eta 0:00:00
# Downloading plotly-6.2.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ------ --------------------------------- 1.6/9.6 MB 6.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.6/9.6 MB 5.8 MB/s eta 0:00:02
#    --------------- ------------------------ 3.7/9.6 MB 5.7 MB/s eta 0:00:02
#    ------------------ --------------------- 4.5/9.6 MB 5.3 MB/s eta 0:00:01
#    -------------------- ------------------- 5.0/9.6 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.8/9.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.6 MB 4.6 MB/s eta 0:00:01
#    ------------------------------ --------- 7.3/9.6 MB 4.4 MB/s eta 0:00:01
#    --------------------------------- ------ 8.1/9.6 MB 4.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.6 MB 4.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.6 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 3.9 MB/s eta 0:00:00
# Downloading python_box-7.3.2-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 3.0 MB/s eta 0:00:00
# Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Downloading scooby-0.10.1-py3-none-any.whl (18 kB)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11019 sha256=542fdbc32fb0b2be6fa93fdf5d66be93be2e2af50dc5bda7c967cdf946af5623
#   Stored in directory: c:\users\sagni\appdata\local\pip\cache\wheels\e8\e7\56\591cb88ba1783b38c40d584026e766aac9c3a048e34128ce8b
# Successfully built pyperclip
# Installing collected packages: pyperclip, colour, xyzservices, traittypes, scooby, ratelim, python-box, pyshp, plotly, jupyter-leaflet, future, geocoder, branca, folium, ipytree, ipyleaflet, ipyfilechooser, ipyevents, bqplot, eerepr, geemap
#
#    ----------- ----------------------------  6/21 [python-box]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    --------------- ------------------------  8/21 [plotly]
#    ------------------- -------------------- 10/21 [future]
#    ------------------- -------------------- 10/21 [future]
#    ------------------- -------------------- 10/21 [future]
#    ------------------- -------------------- 10/21 [future]
#    ------------------- -------------------- 10/21 [future]
#    -------------------- ------------------- 11/21 [geocoder]
#    -------------------- ------------------- 11/21 [geocoder]
#    ------------------------ --------------- 13/21 [folium]
#    -------------------------- ------------- 14/21 [ipytree]
#    ---------------------------------- ----- 18/21 [bqplot]
#    -------------------------------------- - 20/21 [geemap]
#    -------------------------------------- - 20/21 [geemap]
#    -------------------------------------- - 20/21 [geemap]
#    -------------------------------------- - 20/21 [geemap]
#    ---------------------------------------- 21/21 [geemap]
#
# Successfully installed bqplot-0.12.45 branca-0.8.1 colour-0.1.5 eerepr-0.1.2 folium-0.20.0 future-1.0.0 geemap-0.35.3 geocoder-1.38.1 ipyevents-2.0.2 ipyfilechooser-0.6.0 ipyleaflet-0.20.0 ipytree-0.2.2 jupyter-leaflet-0.20.0 plotly-6.2.0 pyperclip-1.9.0 pyshp-2.3.1 python-box-7.3.2 ratelim-0.1.6 scooby-0.10.1 traittypes-0.2.1 xyzservices-2025.4.0
#   DEPRECATION: Building 'pyperclip' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'pyperclip'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Requirement already satisfied: pandas in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (3.7.3)
# Requirement already satisfied: seaborn in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: tensorflow in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (2.18.0)
# Requirement already satisfied: keras in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (3.10.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: rich in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from keras) (14.0.0)
# Requirement already satisfied: namex in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from keras) (0.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from rich->keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: folium in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sagni\appdata\local\programs\python\python311\lib\site-packages (from requests->folium) (2025.1.31)

# %%
import ee

# Authenticate again
ee.Authenticate()

# Initialize Earth Engine
ee.Initialize()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Example: Get Sentinel-5P NO2 data
sentinel5 = ee.ImageCollection('COPERNICUS/S5P/NRTI/L3_NO2') \
    .filterDate('2024-01-01', '2024-12-31') \
    .filterBounds(ee.Geometry.Point(77.1025, 28.7041))  # Delhi

# Reduce to daily mean NO2
def get_daily_mean(image):
    return image.reduceRegion(
        reducer=ee.Reducer.mean(),
        geometry=ee.Geometry.Point(77.1025, 28.7041),
        scale=1000
    ).get('tropospheric_NO2_column_number_density').getInfo()

# Get time series
ee_list = sentinel5.toList(sentinel5.size())
dates = sentinel5.aggregate_array('system:time_start').getInfo()
no2_values = []

for i in range(sentinel5.size().getInfo()):
    img = ee.Image(ee_list.get(i))
    try:
        value = get_daily_mean(img)
    except:
        value = None  # If no data for that day
    no2_values.append(value)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import pandas as pd

# Example dataframe
data = pd.DataFrame({
    'date': pd.to_datetime(dates, unit='ms'),
    'NO2': no2_values,
    # Add CO, O3, Temperature, WindSpeed, Historical AQI
})

data = data.dropna()
data.set_index('date', inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import pandas as pd
import numpy as np

# Create example dataframe
data = pd.DataFrame({
    'date': pd.to_datetime(dates, unit='ms'),
    'NO2': no2_values,
    'CO': np.random.uniform(0.2, 1.0, len(no2_values)),         # Random placeholder
    'O3': np.random.uniform(0.01, 0.05, len(no2_values)),       # Random placeholder
    'Temperature': np.random.uniform(15, 35, len(no2_values)),  # Random placeholder
    'WindSpeed': np.random.uniform(1, 10, len(no2_values)),     # Random placeholder
    'AQI': np.random.randint(50, 200, len(no2_values))          # Random placeholder AQI
})

# Drop rows with any NaN values
data = data.dropna()

# Set date as index
data.set_index('date', inplace=True)

# Save to CSV
save_path = r"C:\Users\sagni\Downloads\Pollution controller\data.csv"
data.to_csv(save_path)

print(f"✅ Data saved successfully at {save_path}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ✅ Data saved successfully at C:\Users\sagni\Downloads\Pollution controller\data.csv
