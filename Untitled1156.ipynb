# %%
# !pip install tsfresh
# Out:
# ...
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.2 MB 1.4 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.2 MB 1.7 MB/s eta 0:00:03
#    ------------ --------------------------- 1.3/4.2 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.1/4.2 MB 2.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.2 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------- -- 3.9/4.2 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 3.1 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pywavelets]
#    ------------- -------------------------- 1/3 [stumpy]
#    -------------------------- ------------- 2/3 [tsfresh]
#    ---------------------------------------- 3/3 [tsfresh]
#
# ...

# %%
# !pip install sktime
# Out:
# ...
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/35.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/35.5 MB 985.5 kB/s eta 0:00:36
#     --------------------------------------- 0.8/35.5 MB 1.1 MB/s eta 0:00:33
#     --------------------------------------- 0.8/35.5 MB 1.1 MB/s eta 0:00:33
#    - -------------------------------------- 1.3/35.5 MB 1.1 MB/s eta 0:00:32
#    - -------------------------------------- 1.6/35.5 MB 1.1 MB/s eta 0:00:32
#    -- ------------------------------------- 1.8/35.5 MB 1.2 MB/s eta 0:00:30
#    -- ------------------------------------- 2.1/35.5 MB 1.2 MB/s eta 0:00:28
#    -- ------------------------------------- 2.4/35.5 MB 1.2 MB/s eta 0:00:28
# ...

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# Load the image
file_path = "C:/Users/sagni/Downloads/Pollution controller/NO2_Latest_India.tif"

with rasterio.open(file_path) as src:
    band = src.read(1)  # Read first (and probably only) band
    profile = src.profile

# Mask invalid values (e.g., -9999 or zeros if needed)
band = np.where(band <= 0, np.nan, band)

# Plot heatmap
plt.figure(figsize=(10, 6))
plt.imshow(band, cmap='inferno')
plt.colorbar(label="NO₂ Concentration")
plt.title("NO₂ Distribution in India")
plt.axis('off')
plt.show()
